# %%
import sympy as sp
import numpy as np
d2r = np.deg2rad

# %%
from sympy.physics.vector import init_vprinting
init_vprinting(use_latex='mathjax', pretty_print=False)

# %%
from sympy.physics.mechanics import dynamicsymbols

# %%
theta1, theta2,theta3,theta4,theta5,theta6,theta7,theta8,theta9,theta10,theta11,d_6,L_Cl, L_Tl, W_l, W_r, L_Tr, L_Cr, theta, alpha, a, d = dynamicsymbols('theta1 theta2 theta3 theta4 theta5 theta6 theta7 theta8 theta9 theta10 theta11 d_6 L_Cl L_Tl W_l W_r L_Tr L_Cr theta alpha a d')
theta1,theta2,theta3,theta4,theta5,theta6,theta7,theta8,theta9,theta10,theta11,d_6,L_Cl, L_Tl, W_l, W_r, L_Tr, L_Cr, theta, alpha, a, d
# Out:
# (theta1, theta2, theta3, theta4, theta5, theta6, theta7, theta8, theta9, theta10, theta11, d_6, L_Cl, L_Tl, W_l, W_r, L_Tr, L_Cr, theta, alpha, a, d)

# %%
rot = sp.Matrix([[sp.cos(theta), -sp.sin(theta)*sp.cos(alpha), sp.sin(theta)*sp.sin(alpha)],
                 [sp.sin(theta), sp.cos(theta)*sp.cos(alpha), -sp.cos(theta)*sp.sin(alpha)],
                 [0, sp.sin(alpha), sp.cos(alpha)]])

trans = sp.Matrix([a*sp.cos(theta),a*sp.sin(theta),d])

last_row = sp.Matrix([[0, 0, 0, 1]])

m = sp.Matrix.vstack(sp.Matrix.hstack(rot, trans), last_row)
m
# Out:
# Matrix([
# [cos(theta), -sin(theta)*cos(alpha),  sin(alpha)*sin(theta), a*cos(theta)],
# [sin(theta),  cos(alpha)*cos(theta), -sin(alpha)*cos(theta), a*sin(theta)],
# [         0,             sin(alpha),             cos(alpha),            d],
# [         0,                      0,                      0,            1]])

# %%
m01 = m.subs({alpha:-sp.pi, a:0, theta:theta1, d:0})
m01
# Out:
# Matrix([
# [cos(theta1),  0, -sin(theta1), 0],
# [sin(theta1),  0,  cos(theta1), 0],
# [          0, -1,            0, 0],
# [          0,  0,            0, 1]])

# %%
m12 = m.subs({alpha:0, a:431.8, theta:theta2, d:149.09})
m12
# Out:
# Matrix([
# [cos(theta2), -sin(theta2), 0, 431.8*cos(theta2)],
# [sin(theta2),  cos(theta2), 0, 431.8*sin(theta2)],
# [          0,            0, 1,            149.09],
# [          0,            0, 0,                 1]])

# %%
m23 = m.subs({alpha:sp.pi/2, a:-20.32, theta:theta3, d:0})
m23
# Out:
# Matrix([
# [cos(theta3), 0,  sin(theta3), -20.32*cos(theta3)],
# [sin(theta3), 0, -cos(theta3), -20.32*sin(theta3)],
# [          0, 1,            0,                  0],
# [          0, 0,            0,                  1]])

# %%
m34 = m.subs({alpha:-sp.pi/2, a:0, theta:theta4,d:433.07})
m34
# Out:
# Matrix([
# [cos(theta4),  0, -sin(theta4),      0],
# [sin(theta4),  0,  cos(theta4),      0],
# [          0, -1,            0, 433.07],
# [          0,  0,            0,      1]])

# %%
m45 = m.subs({alpha:sp.pi/2, a:0, theta:theta5, d:0})
m45
# Out:
# Matrix([
# [cos(theta5), 0,  sin(theta5), 0],
# [sin(theta5), 0, -cos(theta5), 0],
# [          0, 1,            0, 0],
# [          0, 0,            0, 1]])

# %%
m56 = m.subs({alpha:0, a:0, theta:theta6, d:56.25})
m56
# Out:
# Matrix([
# [cos(theta6), -sin(theta6), 0,     0],
# [sin(theta6),  cos(theta6), 0,     0],
# [          0,            0, 1, 56.25],
# [          0,            0, 0,     1]])

# %%
m67 = m.subs({alpha:0, a:0, theta:theta7, d:56.25})
m67
# Out:
# Matrix([
# [cos(theta7), 0,  sin(theta7), W_r*cos(theta7)],
# [sin(theta7), 0, -cos(theta7), W_r*sin(theta7)],
# [          0, 1,            0,               0],
# [          0, 0,            0,               1]])

# %%
m78 = m.subs({alpha:sp.pi/2, a:0, theta:theta3, d:0})
m78
# Out:
# Matrix([
# [cos(theta3), 0,  sin(theta3), 0],
# [sin(theta3), 0, -cos(theta3), 0],
# [          0, 1,            0, 0],
# [          0, 0,            0, 1]])

# %%
m89 = m.subs({alpha:0, a:-L_Tr, theta:theta9, d:0})
m89
# Out:
# Matrix([
# [cos(theta9), -sin(theta9), 0, -L_Tr*cos(theta9)],
# [sin(theta9),  cos(theta9), 0, -L_Tr*sin(theta9)],
# [          0,            0, 1,                 0],
# [          0,            0, 0,                 1]])

# %%
m910 = m.subs({alpha:sp.pi/2, a:L_Cr, theta:theta10, d:0})
m910
# Out:
# Matrix([
# [cos(theta10), 0,  sin(theta10), L_Cr*cos(theta10)],
# [sin(theta10), 0, -cos(theta10), L_Cr*sin(theta10)],
# [           0, 1,             0,                 0],
# [           0, 0,             0,                 1]])

# %%
m1011 = m.subs({alpha:sp.pi/2, a:0, theta:theta11, d:0})
m1011
# Out:
# Matrix([
# [cos(theta11), 0,  sin(theta11), 0],
# [sin(theta11), 0, -cos(theta11), 0],
# [           0, 1,             0, 0],
# [           0, 0,             0, 1]])

# %%
mbee= sp.Matrix([[m02[0,0].simplify(), m02[0,1].simplify(), sp.trigsimp(m02[0,3].simplify())],
                 [m02[1,0].simplify(), m02[1,1].simplify(), sp.trigsimp(m02[1,3].simplify())],
                 [m02[2,0].simplify(), m02[2,1].simplify(), m02[2,2].simplify()]])

mbee
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-9814965604b2> in <module>
# ----> 1 mbee= sp.Matrix([[m02[0,0].simplify(), m02[0,1].simplify(), sp.trigsimp(m02[0,3].simplify())],
#       2                  [m02[1,0].simplify(), m02[1,1].simplify(), sp.trigsimp(m02[1,3].simplify())],
#       3                  [m02[2,0].simplify(), m02[2,1].simplify(), m02[2,2].simplify()]])
#       4
#       5 mbee
#
# NameError: name 'm02' is not defined

# %%
m011=(m01*m12*m23*m34*m45*m56*m67*m78*m89*m910*m1011)
m011
# Out:
# Matrix([
# ...

# %%
px=m011[0,3]
px
# Out:
# (-(((((-(sin(theta1)*sin(theta3) + cos(theta1)*cos(theta2)*cos(theta3))*sin(theta4) + sin(theta2)*cos(theta1)*cos(theta4))*sin(theta5) + ((sin(theta1)*sin(theta3) + cos(theta1)*cos(theta2)*cos(theta3))*cos(theta4) + sin(theta2)*sin(theta4)*cos(theta1))*cos(theta5))*cos(theta6) + (-sin(theta1)*cos(theta3) + sin(theta3)*cos(theta1)*cos(theta2))*sin(theta6))*cos(theta7) + (-(-(sin(theta1)*sin(theta3) + cos(theta1)*cos(theta2)*cos(theta3))*sin(theta4) + sin(theta2)*cos(theta1)*cos(theta4))*cos(theta5) + ((sin(theta1)*sin(theta3) + cos(theta1)*cos(theta2)*cos(theta3))*cos(theta4) + sin(theta2)*sin(theta4)*cos(theta1))*sin(theta5))*sin(theta7))*cos(theta3) + (((-(sin(theta1)*sin(theta3) + cos(theta1)*cos(theta2)*cos(theta3))*sin(theta4) + sin(theta2)*cos(theta1)*cos(theta4))*sin(theta5) + ((sin(theta1)*sin(theta3) + cos(theta1)*cos(theta2)*cos(theta3))*cos(theta4) + sin(theta2)*sin(theta4)*cos(theta1))*cos(theta5))*sin(theta6) - (-sin(theta1)*cos(theta3) + sin(theta3)*cos(theta1)*cos(theta
# ...

# %%
val=px.subs({theta1=sp.pi,theta2=-sp.pi/2, theta3=sp.pi,theta4=0,theta5=sp.pi,theta6=-sp.pi/2,theta7=sp.pi,theta8=-sp.pi/2,theta9=0,theta10=sp.pi,theta11=sp.pi,d_6=12,L_Cl=50, L_Tl=50, W_l=30, W_r=30, L_Tr=50, L_Cr=50})
# Out:
#   File "<ipython-input-44-1acf05901b44>", line 1
#     val=px.subs({theta1=sp.pi,theta2=-sp.pi/2, theta3=sp.pi,theta4=0,theta5=sp.pi,theta6=-sp.pi/2,theta7=sp.pi,theta8=-sp.pi/2,theta9=0,theta10=sp.pi,theta11=sp.pi,d_6=12,L_Cl=50, L_Tl=50, W_l=30, W_r=30, L_Tr=50, L_Cr=50})
#                        ^
# SyntaxError: invalid syntax

# %%
val=px.subs({theta1:sp.pi,theta2:-sp.pi/2, theta3:sp.pi,theta4:0,theta5:sp.pi,theta6:-sp.pi/2,theta7:sp.pi,theta8:sp.pi/2,theta9:0,theta10:sp.pi,theta11:sp.pi,d_6:12,L_Cl:50, L_Tl:50, W_l:30, W_r:30, L_Tr:50, L_Cr:50})

# %%
val
# Out:
# 12

# %%
py=m011[1,3]
val=py.subs({theta1:sp.pi,theta2:-sp.pi/2, theta3:sp.pi,theta4:0,theta5:sp.pi,theta6:-sp.pi/2,theta7:sp.pi,theta8:sp.pi/2,theta9:0,theta10:sp.pi,theta11:sp.pi,d_6:12,L_Cl:50, L_Tl:50, W_l:30, W_r:30, L_Tr:50, L_Cr:50})

# %%
val
# Out:
# 160

# %%
m_temp=m01*m12*m23*m34*m45*m56
m_temp
# Out:
# Matrix([
# ...

# %%
pz=m_temp[2,3]
pz
val=pz.subs({theta1:sp.pi,theta2:-sp.pi/2, theta3:sp.pi,theta4:0,theta5:sp.pi,theta6:-sp.pi/2,theta7:sp.pi,theta8:sp.pi/2,theta9:0,theta10:sp.pi,theta11:sp.pi,d_6:12,L_Cl:50, L_Tl:50, W_l:30, W_r:30, L_Tr:50, L_Cr:50})
val
# Out:
# -100

# %%
m_disp=m_temp.subs({theta1:sp.pi/2,theta2:0, theta3:sp.pi/2,theta4:0,theta5:0,theta6:0})
m_disp
# Out:
# Matrix([
# [ 0, -1, 0, -149.09],
# [ 0,  0, 1,  921.12],
# [-1,  0, 0,   20.32],
# [ 0,  0, 0,       1]])
